# %% [markdown]
# # Project 3: Data Cleaning - Tidy up messy Datasets (Movies Dataset)

# %% [markdown]
# Through this project, we will accomplish the following important tasks:
#   * Dropping irrelevant Columns
#   * Handle stringified JSON columns
#   * Flatten nested Columns
#   * Clean Numerical Columns
#   * Clean Columns with DateTime Information
#   * Clean String Text Columns
#   * Remove Duplicates
#   * Handle Missing Values & Removing ObervationsRows
#   * Save our new clean dataset

# %% [markdown]
# ## First Steps

# %% [markdown]
# 1. __Load__ and __inspect__ the messy dataset __movies_metadata.csv__. Identify columns with nested / stringified json data.

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("movies_metadata.csv")
data.head()
# Out:
# D:\Programmes\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
data["genres"][0]
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
data["belongs_to_collection"][0]
# Out:
# "{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}"

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
data.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %% [markdown]
# ## Dropping irrelevant Columns

# %% [markdown]
# 2. __Drop__ the irrelevant columns 'adult', 'imdb_id', 'original_title', 'video' and 'homepage'.

# %%
data.drop(columns = ["adult","imdb_id","original_title", "video", "homepage"], axis = 1, inplace = True)

# %% [markdown]
# ## How to handle stringified JSON columns

# %% [markdown]
# 3. __Evaluate__ Python Expressions in the stringified columns ["belongs_to_collection", "genres", "production_countries", "production_companies", "spoken_languages"] and __remove quotes__ ("") where possible.

# %%
import json
import ast

# %%
json_col = ["belongs_to_collection", "genres", "production_countries", 
            "production_companies", "spoken_languages"]

# %%
data.belongs_to_collection[0]
# Out:
# "{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}"

# %%
json1 =  "{'dog':3, 'cat':5}"

# %%
json2 = '{"dog":3, "cat":5}'

# %%
json1.replace("'", '"')
# Out:
# '{"dog":3, "cat":5}'

# %%
json.loads(json1.replace("'", '"'))
# Out:
# {'dog': 3, 'cat': 5}

# %%
data.genres.apply(lambda x: json.loads(x.replace("'", '"')))[0]
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
data.genres = data.genres.apply(ast.literal_eval)
data.genres
# Out:
# 0        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                           [{'id': 35, 'name': 'Comedy'}]
#                                ...
# 45461    [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                        [{'id': 18, 'name': 'Drama'}]
# 45463    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                   []
# 45465                                                   []
# Name: genres, Length: 45466, dtype: object

# %%
data.belongs_to_collection
# Out:
# 0        {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                      NaN
# 2        {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                      NaN
# 4        {'id': 96871, 'name': 'Father of the Bride Col...
#                                ...
# 45461                                                  NaN
# 45462                                                  NaN
# 45463                                                  NaN
# 45464                                                  NaN
# 45465                                                  NaN
# Name: belongs_to_collection, Length: 45466, dtype: object

# %%
data.belongs_to_collection.apply(lambda x: isinstance(x, str))
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 45461    False
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# Name: belongs_to_collection, Length: 45466, dtype: bool

# %%
data.belongs_to_collection = data.belongs_to_collection.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %%
data.belongs_to_collection [0]
# Out:
# {'id': 10194,
#  'name': 'Toy Story Collection',
#  'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg',
#  'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}

# %%
data.spoken_languages = data.spoken_languages.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %%
data.spoken_languages
# Out:
# 0                 [{'iso_639_1': 'en', 'name': 'English'}]
# 1        [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2                 [{'iso_639_1': 'en', 'name': 'English'}]
# 3                 [{'iso_639_1': 'en', 'name': 'English'}]
# 4                 [{'iso_639_1': 'en', 'name': 'English'}]
#                                ...
# 45461               [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462                    [{'iso_639_1': 'tl', 'name': ''}]
# 45463             [{'iso_639_1': 'en', 'name': 'English'}]
# 45464                                                   []
# 45465             [{'iso_639_1': 'en', 'name': 'English'}]
# Name: spoken_languages, Length: 45466, dtype: object

# %%
data.production_countries = data.production_countries.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %%
data.production_companies = data.production_companies.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %% [markdown]
# ## How to flatten nested Columns

# %% [markdown]
# 4. __Extract__ only the __collection name__ from the column "belongs_to_collection" and __overwrite__ "belongs_to_collection". <br> For example: The value in the first row (Toy Story) should be 'Toy Story Collection'.

# %%
data.belongs_to_collection[0]
# Out:
# {'id': 10194,
#  'name': 'Toy Story Collection',
#  'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg',
#  'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}

# %%
data["belongs_to_collection"] = data["belongs_to_collection"].apply(lambda x: x['name'] if isinstance(x, dict)
                                                                                          else np.nan)

# %%
data.belongs_to_collection.value_counts(dropna=False).head()
# Out:
# NaN                              40975
# The Bowery Boys                     29
# Totò Collection                     27
# Zatôichi: The Blind Swordsman       26
# James Bond Collection               26
# Name: belongs_to_collection, dtype: int64

# %% [markdown]
# 5. __Extract__ all __genre names__ from the column "genres" and __overwrite__ "genres". If a movie has more than one genre, __seperate genres by a pipe__ "|".<br>
# For example: The value in the first row (Toy Story) should be 'Animation|Comedy|Family'.

# %%
data.genres[0]
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
data.genres = data.genres.apply(lambda x: "|".join(i['name'] for i in x))

# %%
data["genres"][0]
# Out:
# 'Animation|Comedy|Family'

# %% [markdown]
# 6. __Extract__ all __spoken language names__ from the column "spoken_languages" and __overwrite__ "spoken_languages". If a movie has more than one spoken language, __seperate spoken languages by a pipe__ "|".<br>
# For example: The value in the first row (Toy Story) should be 'English'.

# %%
data["spoken_languages"].head()
# Out:
# 0             [{'iso_639_1': 'en', 'name': 'English'}]
# 1    [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2             [{'iso_639_1': 'en', 'name': 'English'}]
# 3             [{'iso_639_1': 'en', 'name': 'English'}]
# 4             [{'iso_639_1': 'en', 'name': 'English'}]
# Name: spoken_languages, dtype: object

# %%
data["spoken_languages"] = data["spoken_languages"].apply(lambda x: "|".join(i["name"] for i in x) if isinstance(x, list) else np.nan) 
data["spoken_languages"].isna().sum()
# Out:
# 6

# %% [markdown]
# 7. __Extract__ all __production countries names__ from the column "production_countries" and __overwrite__ "production_countries". If a movie has more than one production country, __seperate production countries by a pipe__ "|".<br>
# For example: The value in the first row (Toy Story) should be 'United States of America'.

# %%
data["production_countries"].head()
# Out:
# 0    [{'iso_3166_1': 'US', 'name': 'United States o...
# 1    [{'iso_3166_1': 'US', 'name': 'United States o...
# 2    [{'iso_3166_1': 'US', 'name': 'United States o...
# 3    [{'iso_3166_1': 'US', 'name': 'United States o...
# 4    [{'iso_3166_1': 'US', 'name': 'United States o...
# Name: production_countries, dtype: object

# %%
data["production_countries"] = data["production_countries"].apply(lambda x: "|".join(i["name"] for i in x) if isinstance(x, list) else np.nan)

# %%
data.T
# Out:
#                                                                    0      \
# belongs_to_collection                               Toy Story Collection
# budget                                                          30000000
# genres                                           Animation|Comedy|Family
# id                                                                   862
# original_language                                                     en
# overview               Led by Woody, Andy's toys live happily in his ...
# popularity                                                       21.9469
# poster_path                             /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# production_companies      [{'name': 'Pixar Animation Studios', 'id': 3}]
# production_countries                            United States of America
# release_date                                                  1995-10-30
# revenue                                                      3.73554e+08
# runtime                                                               81
# spoken_languages                                                 English
# status                                                          Released
# tagline                                                              NaN
# title                                                          Toy Story
# vote_average                                                         7.7
# vote_count                                                          5415
#
#                                                                    1      \
# belongs_to_collection                                                NaN
# budget                                                          65000000
# genres                                          Adventure|Fantasy|Family
# id                                                                  8844
# original_language                                                     en
# overview               When siblings Judy and Peter discover an encha...
# popularity                                                       17.0155
# poster_path                             /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# production_companies   [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# production_countries                            United States of America
# release_date                                                  1995-12-15
# revenue                                                      2.62797e+08
# runtime                                                              104
# spoken_languages                                        English|Français
# status                                                          Released
# tagline                        Roll the dice and unleash the excitement!
# title                                                            Jumanji
# vote_average                                                         6.9
# vote_count                                                          2413
#
#                                                                    2      \
# belongs_to_collection                          Grumpy Old Men Collection
# budget                                                                 0
# genres                                                    Romance|Comedy
# id                                                                 15602
# original_language                                                     en
# overview               A family wedding reignites the ancient feud be...
# popularity                                                       11.7129
# poster_path                             /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# production_companies   [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# production_countries                            United States of America
# release_date                                                  1995-12-22
# revenue                                                                0
# runtime                                                              101
# spoken_languages                                                 English
# status                                                          Released
# tagline                Still Yelling. Still Fighting. Still Ready for...
# title                                                   Grumpier Old Men
# vote_average                                                         6.5
# vote_count                                                            92
#
#                                                                    3      \
# belongs_to_collection                                                NaN
# budget                                                          16000000
# genres                                              Comedy|Drama|Romance
# id                                                                 31357
# original_language                                                     en
# overview               Cheated on, mistreated and stepped on, the wom...
# popularity                                                       3.85949
# poster_path                             /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# production_companies   [{'name': 'Twentieth Century Fox Film Corporat...
# production_countries                            United States of America
# release_date                                                  1995-12-22
# revenue                                                      8.14522e+07
# runtime                                                              127
# spoken_languages                                                 English
# status                                                          Released
# tagline                Friends are the people who let you be yourself...
# title                                                  Waiting to Exhale
# vote_average                                                         6.1
# vote_count                                                            34
#
#                                                                    4      \
# belongs_to_collection                     Father of the Bride Collection
# budget                                                                 0
# genres                                                            Comedy
# id                                                                 11862
# original_language                                                     en
# overview               Just when George Banks has recovered from his ...
# popularity                                                       8.38752
# poster_path                             /e64sOI48hQXyru7naBFyssKFxVd.jpg
# production_companies   [{'name': 'Sandollar Productions', 'id': 5842}...
# production_countries                            United States of America
# release_date                                                  1995-02-10
# revenue                                                      7.65789e+07
# runtime                                                              106
# spoken_languages                                                 English
# status                                                          Released
# tagline                Just When His World Is Back To Normal... He's ...
# title                                        Father of the Bride Part II
# vote_average                                                         5.7
# vote_count                                                           173
#
#                                                                    5      \
# belongs_to_collection                                                NaN
# budget                                                          60000000
# genres                                       Action|Crime|Drama|Thriller
# id                                                                   949
# original_language                                                     en
# overview               Obsessive master thief, Neil McCauley leads a ...
# popularity                                                       17.9249
# poster_path                             /zMyfPUelumio3tiDKPffaUpsQTD.jpg
# production_companies   [{'name': 'Regency Enterprises', 'id': 508}, {...
# production_countries                            United States of America
# release_date                                                  1995-12-15
# revenue                                                      1.87437e+08
# runtime                                                              170
# spoken_languages                                         English|Español
# status                                                          Released
# tagline                                         A Los Angeles Crime Saga
# title                                                               Heat
# vote_average                                                         7.7
# vote_count                                                          1886
#
#                                                                    6      \
# belongs_to_collection                                                NaN
# budget                                                          58000000
# genres                                                    Comedy|Romance
# id                                                                 11860
# original_language                                                     en
# overview               An ugly duckling having undergone a remarkable...
# popularity                                                       6.67728
# poster_path                             /jQh15y5YB7bWz1NtffNZmRw0s9D.jpg
# production_companies   [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# production_countries                    Germany|United States of America
# release_date                                                  1995-12-15
# revenue                                                                0
# runtime                                                              127
# spoken_languages                                        Français|English
# status                                                          Released
# tagline                You are cordially invited to the most surprisi...
# title                                                            Sabrina
# vote_average                                                         6.2
# vote_count                                                           141
#
#                                                                    7      \
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                     Action|Adventure|Drama|Family
# id                                                                 45325
# original_language                                                     en
# overview               A mischievous young boy, Tom Sawyer, witnesses...
# popularity                                                       2.56116
# poster_path                             /sGO5Qa55p7wTu7FJcX4H4xIVKvS.jpg
# production_companies         [{'name': 'Walt Disney Pictures', 'id': 2}]
# production_countries                            United States of America
# release_date                                                  1995-12-22
# revenue                                                                0
# runtime                                                               97
# spoken_languages                                         English|Deutsch
# status                                                          Released
# tagline                                           The Original Bad Boys.
# title                                                       Tom and Huck
# vote_average                                                         5.4
# vote_count                                                            45
#
#                                                                    8      \
# belongs_to_collection                                                NaN
# budget                                                          35000000
# genres                                         Action|Adventure|Thriller
# id                                                                  9091
# original_language                                                     en
# overview               International action superstar Jean Claude Van...
# popularity                                                       5.23158
# poster_path                             /eoWvKD60lT95Ss1MYNgVExpo5iU.jpg
# production_companies   [{'name': 'Universal Pictures', 'id': 33}, {'n...
# production_countries                            United States of America
# release_date                                                  1995-12-22
# revenue                                                      6.43502e+07
# runtime                                                              106
# spoken_languages                                                 English
# status                                                          Released
# tagline                                       Terror goes into overtime.
# title                                                       Sudden Death
# vote_average                                                         5.5
# vote_count                                                           174
#
#                                                                    9      ...  \
# belongs_to_collection                              James Bond Collection  ...
# budget                                                          58000000  ...
# genres                                         Adventure|Action|Thriller  ...
# id                                                                   710  ...
# original_language                                                     en  ...
# overview               James Bond must unmask the mysterious head of ...  ...
# popularity                                                        14.686  ...
# poster_path                             /5c0ovjT41KnYIHYuF4AWsTe3sKh.jpg  ...
# production_companies   [{'name': 'United Artists', 'id': 60}, {'name'...  ...
# production_countries             United Kingdom|United States of America  ...
# release_date                                                  1995-11-16  ...
# revenue                                                      3.52194e+08  ...
# runtime                                                              130  ...
# spoken_languages                                 English|Pусский|Español  ...
# status                                                          Released  ...
# tagline                             No limits. No fears. No substitutes.  ...
# title                                                          GoldenEye  ...
# vote_average                                                         6.6  ...
# vote_count                                                          1194  ...
#
#                                                                    45456  \
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                           Horror|Mystery|Thriller
# id                                                                 84419
# original_language                                                     en
# overview               An unsuccessful sculptor saves a madman named ...
# popularity                                                      0.222814
# poster_path                             /yMnq9mL5uYxbRgwKqyz1cVGCJYJ.jpg
# production_companies          [{'name': 'Universal Pictures', 'id': 33}]
# production_countries                            United States of America
# release_date                                                  1946-03-29
# revenue                                                                0
# runtime                                                               65
# spoken_languages                                                 English
# status                                                          Released
# tagline                                              Meet...The CREEPER!
# title                                                   House of Horrors
# vote_average                                                         6.3
# vote_count                                                             8
#
#                                                                    45457  \
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                                    Mystery|Horror
# id                                                                390959
# original_language                                                     en
# overview               In this true-crime documentary, we delve into ...
# popularity                                                      0.076061
# poster_path                             /q75tCM4pFmUzdCg0gqcOQquCaYf.jpg
# production_companies                                                  []
# production_countries
# release_date                                                  2000-10-22
# revenue                                                                0
# runtime                                                               45
# spoken_languages                                                 English
# status                                                          Released
# tagline                                                              NaN
# title                                          Shadow of the Blair Witch
# vote_average                                                           7
# vote_count                                                             2
#
#                                                                    45458  \
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                                            Horror
# id                                                                289923
# original_language                                                     en
# overview               A film archivist revisits the story of Rustin ...
# popularity                                                       0.38645
# poster_path                             /lXtoHVdej6kS1Dc7KAhw05sMos9.jpg
# production_companies   [{'name': 'Neptune Salad Entertainment', 'id':...
# production_countries                            United States of America
# release_date                                                  2000-10-03
# revenue                                                                0
# runtime                                                               30
# spoken_languages                                                 English
# status                                                          Released
# tagline                Do you know what happened 50 years before "The...
# title                                                The Burkittsville 7
# vote_average                                                           7
# vote_count                                                             1
#
#                                                                    45459  \
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                                   Science Fiction
# id                                                                222848
# original_language                                                     en
# overview               It's the year 3000 AD. The world's most danger...
# popularity                                                      0.661558
# poster_path                             /4lF9LH0b0Z1X94xGK9IOzqEW6k1.jpg
# production_companies     [{'name': 'Concorde-New Horizons', 'id': 4688}]
# production_countries                            United States of America
# release_date                                                  1995-01-01
# revenue                                                                0
# runtime                                                               85
# spoken_languages                                                 English
# status                                                          Released
# tagline                                                              NaN
# title                                                    Caged Heat 3000
# vote_average                                                         3.5
# vote_count                                                             1
#
#                                                                    45460  \
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                              Drama|Action|Romance
# id                                                                 30840
# original_language                                                     en
# overview               Yet another version of the classic epic, with ...
# popularity                                                      5.683753
# poster_path                             /fQC46NglNiEMZBv5XHoyLuOWoN5.jpg
# production_companies   [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# production_countries   Canada|Germany|United Kingdom|United States of...
# release_date                                                  1991-05-13
# revenue                                                                0
# runtime                                                              104
# spoken_languages                                                 English
# status                                                          Released
# tagline                                                              NaN
# title                                                         Robin Hood
# vote_average                                                         5.7
# vote_count                                                            26
#
#                                                              45461  \
# belongs_to_collection                                          NaN
# budget                                                           0
# genres                                                Drama|Family
# id                                                          439050
# original_language                                               fa
# overview               Rising and falling between a man and woman.
# popularity                                                0.072051
# poster_path                       /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# production_companies                                            []
# production_countries                                          Iran
# release_date                                                   NaN
# revenue                                                          0
# runtime                                                         90
# spoken_languages                                             فارسی
# status                                                    Released
# tagline                 Rising and falling between a man and woman
# title                                                       Subdue
# vote_average                                                     4
# vote_count                                                       1
#
#                                                                    45462  \
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                                             Drama
# id                                                                111109
# original_language                                                     tl
# overview               An artist struggles to finish his work while a...
# popularity                                                      0.178241
# poster_path                             /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# production_companies              [{'name': 'Sine Olivia', 'id': 19653}]
# production_countries                                         Philippines
# release_date                                                  2011-11-17
# revenue                                                                0
# runtime                                                              360
# spoken_languages
# status                                                          Released
# tagline                                                              NaN
# title                                                Century of Birthing
# vote_average                                                           9
# vote_count                                                             3
#
#                                                                    45463  \
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                             Action|Drama|Thriller
# id                                                                 67758
# original_language                                                     en
# overview               When one of her hits goes wrong, a professiona...
# popularity                                                      0.903007
# poster_path                             /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# production_companies   [{'name': 'American World Pictures', 'id': 6165}]
# production_countries                            United States of America
# release_date                                                  2003-08-01
# revenue                                                                0
# runtime                                                               90
# spoken_languages                                                 English
# status                                                          Released
# tagline                                           A deadly game of wits.
# title                                                           Betrayal
# vote_average                                                         3.8
# vote_count                                                             6
#
#                                                                    45464  \
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres
# id                                                                227506
# original_language                                                     en
# overview               In a small town live two brothers, one a minis...
# popularity                                                      0.003503
# poster_path                             /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# production_companies                [{'name': 'Yermoliev', 'id': 88753}]
# production_countries                                              Russia
# release_date                                                  1917-10-21
# revenue                                                                0
# runtime                                                               87
# spoken_languages
# status                                                          Released
# tagline                                                              NaN
# title                                                   Satan Triumphant
# vote_average                                                           0
# vote_count                                                             0
#
#                                                                    45465
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres
# id                                                                461257
# original_language                                                     en
# overview               50 years after decriminalisation of homosexual...
# popularity                                                      0.163015
# poster_path                             /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
# production_companies                                                  []
# production_countries                                      United Kingdom
# release_date                                                  2017-06-09
# revenue                                                                0
# runtime                                                               75
# spoken_languages                                                 English
# status                                                          Released
# tagline                                                              NaN
# title                                                           Queerama
# vote_average                                                           0
# vote_count                                                             0
#
# [19 rows x 45466 columns]

# %% [markdown]
# 8. __Extract__ all __production companies names__ from the column "production_companies" and __overwrite__ "production_companies". If a movie has more than one production company, __seperate production companies by a pipe__ "|".<br>
# For example: The value in the first row (Toy Story) should be 'Pixar Animation Studios'

# %%
data.production_companies = data.production_companies.apply(lambda x: "|".join(i["name"] for i in x) if isinstance(x, list) else np.nan)

# %%
data.production_companies.head(10)
# Out:
# 0                              Pixar Animation Studios
# 1    TriStar Pictures|Teitler Film|Interscope Commu...
# 2                          Warner Bros.|Lancaster Gate
# 3               Twentieth Century Fox Film Corporation
# 4            Sandollar Productions|Touchstone Pictures
# 5        Regency Enterprises|Forward Pass|Warner Bros.
# 6    Paramount Pictures|Scott Rudin Productions|Mir...
# 7                                 Walt Disney Pictures
# 8    Universal Pictures|Imperial Entertainment|Sign...
# 9                       United Artists|Eon Productions
# Name: production_companies, dtype: object

# %%
data.isna().sum()
# Out:
# belongs_to_collection    40975
# budget                       0
# genres                       0
# id                           0
# original_language           11
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         6
# production_countries         6
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
pd.read_csv("movies_metadata.csv", low_memory=False).isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %% [markdown]
# ## Cleaning Numerical Columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget                 45466 non-null  object
#  2   genres                 45466 non-null  object
#  3   id                     45466 non-null  object
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45461 non-null  object
#  7   poster_path            45080 non-null  object
#  8   production_companies   45460 non-null  object
#  9   production_countries   45460 non-null  object
#  10  release_date           45379 non-null  object
#  11  revenue                45460 non-null  float64
#  12  runtime                45203 non-null  float64
#  13  spoken_languages       45460 non-null  object
#  14  status                 45379 non-null  object
#  15  tagline                20412 non-null  object
#  16  title                  45460 non-null  object
#  17  vote_average           45460 non-null  float64
#  18  vote_count             45460 non-null  float64
# dtypes: float64(4), object(15)
# memory usage: 6.6+ MB

# %% [markdown]
# 10. __Convert__ the datatype in the columns __"budget"__, __"id"__ and __"popularity"__ __to numeric__. Set invalid values as NaN.

# %%
data["budget"] =pd.to_numeric(data.budget, errors="coerce")

# %%
data.budget = data.budget.replace(0, np.nan)

# %%
data.budget.value_counts(dropna = False)
# Out:
# NaN           36576
# 5000000.0       286
# 10000000.0      259
# 20000000.0      243
# 2000000.0       242
#               ...
# 4490331.0         1
# 313411.0          1
# 1020000.0         1
# 37.0              1
# 9500.0            1
# Name: budget, Length: 1223, dtype: int64

# %%
data["id"] = pd.to_numeric(data.id, errors="coerce")

# %%
data.id.value_counts(dropna = False)
# Out:
# 141971.0    3
# NaN         3
# 12600.0     2
# 18440.0     2
# 42495.0     2
#            ..
# 41244.0     1
# 10518.0     1
# 55971.0     1
# 91070.0     1
# 1408.0      1
# Name: id, Length: 45434, dtype: int64

# %%
data["popularity"] = pd.to_numeric(data.popularity, errors="coerce")

# %%
data.popularity.value_counts(dropna = False)
# Out:
# 0.000000     66
# 0.000001     56
# 0.000308     43
# 0.000220     40
# 0.000578     38
#              ..
# 10.066776     1
# 0.954314      1
# 1.874027      1
# 0.512893      1
# 5.603312      1
# Name: popularity, Length: 43758, dtype: int64

# %% [markdown]
# 11. __Analyze__ the columns __"budget"__ and __"revenue"__ and __"runtime"__. Analyze movies with a budget/revenue/runtime of 0. Do you think the value 0 is the most appropriate value? __Take reasonable measures__!

# %%
data[data["runtime"] == 0]
# Out:
#                 belongs_to_collection    budget                    genres  \
# 222                               NaN       NaN                  Thriller
# 224                               NaN       NaN      Crime|Comedy|Fantasy
# 398                               NaN       NaN
# 554                               NaN       NaN
# 667                               NaN       NaN             Drama|Romance
# ...                               ...       ...                       ...
# 45370                             NaN       NaN                     Drama
# 45371  DC Super Hero Girls Collection       NaN                 Animation
# 45399                             NaN  750000.0              Crime|Comedy
# 45416                             NaN       NaN                    Comedy
# 45430                             NaN       NaN  Thriller|Science Fiction
#
#              id original_language  \
# 222     61813.0                en
# 224     62488.0                it
# 398    172923.0                en
# 554    218473.0                en
# 667    221917.0                en
# ...         ...               ...
# 45370  374764.0                es
# 45371  460135.0                en
# 45399  280422.0                ru
# 45416  282308.0                en
# 45430  222872.0                en
#
#                                                 overview  popularity  \
# 222    Kris is a homicide cop with psychic abilities....    0.155859
# 224    Johnny Destiny burns into Las Vegas in his hot...    0.710671
# 398    Greed and playing into the hand of providence ...    0.233376
# 554    The Beans are poor, proud, hated by all, but a...    0.382470
# 667    An Irish lad (Matt Keeslar) who fled from his ...    0.117662
# ...                                                  ...         ...
# 45370  Celina works at a remote tollbooth on a desert...    0.274793
# 45371  When Supergirl, Wonder Woman, Batgirl, Bumbleb...    8.413734
# 45399                                                NaN    0.201582
# 45416  After visiting the first Cubist exposition in ...    0.003732
# 45430            Sci-fi thriller directed by Fred Gallo.    1.188052
#
#                             poster_path  \
# 222    /7JbvfOA2hnWkSIJslAayK0AemDU.jpg
# 224    /9iczUcmMLnOZ4Ltx3X3AEpbxTt4.jpg
# 398    /1L15fJfWfOUK9Ht15OLLmgW90h8.jpg
# 554                                 NaN
# 667    /ngOBDDwr5CpzFx9IJljq1CfOGt3.jpg
# ...                                 ...
# 45370  /cMsD2BSDgXuHceypiKc0jW5r7Iz.jpg
# 45371  /niLX2txdI5GlVowJlnb5Hr26QpK.jpg
# 45399  /hNsmPpl3zLG36jr4EIEd5P8I4pa.jpg
# 45416  /rGi2o6TDQhiYeaYQqPQkwKx8qfJ.jpg
# 45430  /kYRubwfzgCk9IM3MyJtslCGO1TH.jpg
#
#                                     production_companies  \
# 222          Keystone Pictures|Dream Man Productions Inc
# 224                  Savoy Pictures|Rysher Entertainment
# 398
# 554
# 667    Castle Rock Entertainment|Columbia Pictures Co...
# ...                                                  ...
# 45370                                         Tarea Fina
# 45371                             Warner Bros. Animation
# 45399               Кинокомпания «Lunapark»|Инвада фильм
# 45416                                       Pathé Frères
# 45430                                  The Pacific Trust
#
#                    production_countries release_date  revenue  runtime  \
# 222     United States of America|Canada   1995-01-01      0.0      0.0
# 224            United States of America   1995-04-28      0.0      0.0
# 398                                       1995-05-26      0.0      0.0
# 554                                       1994-01-01      0.0      0.0
# 667    Ireland|United States of America   1995-09-22      0.0      0.0
# ...                                 ...          ...      ...      ...
# 45370                         Argentina   2015-11-12      0.0      0.0
# 45371          United States of America   2017-08-30      0.0      0.0
# 45399                            Russia   2014-06-05      3.0      0.0
# 45416                            France   1912-01-01      0.0      0.0
# 45430          United States of America   1996-01-01      0.0      0.0
#
#                spoken_languages    status  \
# 222                     English  Released
# 224                     English  Released
# 398                              Released
# 554                              Released
# 667                     English  Released
# ...                         ...       ...
# 45370                   Español  Released
# 45371  English|Polski|Português  Released
# 45399                   Pусский  Released
# 45416                  Français  Released
# 45430                            Released
#
#                                     tagline  \
# 222                                     NaN
# 224    Fate visits in ways you never expect
# 398                                     NaN
# 554                                     NaN
# 667                An unforgettable romance
# ...                                     ...
# 45370                                   NaN
# 45371                                   NaN
# 45399                                   NaN
# 45416                                   NaN
# 45430                                   NaN
#
#                                        title  vote_average  vote_count
# 222                                Dream Man           2.5         1.0
# 224               Destiny Turns on the Radio           5.3         9.0
# 398                             Dos Crímenes           5.0         1.0
# 554                The Beans of Egypt, Maine           0.0         1.0
# 667                   The Run of the Country           8.0         2.0
# ...                                      ...           ...         ...
# 45370                   How Most Things Work           6.8         2.0
# 45371  LEGO DC Super Hero Girls: Brain Drain          10.0         2.0
# 45399                            All at Once           6.0         4.0
# 45416                 Whiffles, Cubic Artist           0.0         0.0
# 45430                           Starquest II           2.0         1.0
#
# [1558 rows x 19 columns]

# %%
data.budget = data.budget.replace(0, np.nan)

# %%
data["budget"].value_counts(dropna = False)
# Out:
# NaN           36576
# 5000000.0       286
# 10000000.0      259
# 20000000.0      243
# 2000000.0       242
#               ...
# 4490331.0         1
# 313411.0          1
# 1020000.0         1
# 37.0              1
# 9500.0            1
# Name: budget, Length: 1223, dtype: int64

# %% [markdown]
# 12. The columns "budget" and "revenue" shall show values in Million USD. __Convert and Overwrite__!

# %%
data.budget = data.budget.div(1000000)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4491 non-null   object
#  1   budget                 8890 non-null   float64
#  2   genres                 45466 non-null  object
#  3   id                     45463 non-null  float64
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45460 non-null  float64
#  7   poster_path            45080 non-null  object
#  8   production_companies   45460 non-null  object
#  9   production_countries   45460 non-null  object
#  10  release_date           45379 non-null  object
#  11  revenue                45460 non-null  float64
#  12  runtime                45203 non-null  float64
#  13  spoken_languages       45460 non-null  object
#  14  status                 45379 non-null  object
#  15  tagline                20412 non-null  object
#  16  title                  45460 non-null  object
#  17  vote_average           45460 non-null  float64
#  18  vote_count             45460 non-null  float64
# dtypes: float64(7), object(12)
# memory usage: 6.6+ MB

# %%
data.revenue = data.revenue.div(1000000)

# %%
data.revenue.head()
# Out:
# 0    373.554033
# 1    262.797249
# 2      0.000000
# 3     81.452156
# 4     76.578911
# Name: revenue, dtype: float64

# %%
data.rename(columns = {"revenue":"revenue_musd", "budget":"budget_musd"}, inplace = True)

# %% [markdown]
# 13. __Analyze__ movies with a __vote_count of 0__. What´s the __vote_average__ for those movies? Do you think this value is the most appropriate value? __Take reasonable measures__!

# %%
data[data["vote_count"] == 0].mean()
# Out:
# budget_musd          1.440008
# id              201123.499828
# popularity           0.166369
# revenue_musd         0.013577
# runtime             76.394286
# vote_average         0.000000
# vote_count           0.000000
# dtype: float64

# %%
data[data["vote_average"] == 0] = np.nan

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4428 non-null   object
#  1   budget_musd            8794 non-null   float64
#  2   genres                 42468 non-null  object
#  3   id                     42465 non-null  float64
#  4   original_language      42462 non-null  object
#  5   overview               41716 non-null  object
#  6   popularity             42462 non-null  float64
#  7   poster_path            42359 non-null  object
#  8   production_companies   42462 non-null  object
#  9   production_countries   42462 non-null  object
#  10  release_date           42432 non-null  object
#  11  revenue_musd           42462 non-null  float64
#  12  runtime                42304 non-null  float64
#  13  spoken_languages       42462 non-null  object
#  14  status                 42406 non-null  object
#  15  tagline                19750 non-null  object
#  16  title                  42462 non-null  object
#  17  vote_average           42462 non-null  float64
#  18  vote_count             42462 non-null  float64
# dtypes: float64(7), object(12)
# memory usage: 6.6+ MB

# %% [markdown]
# ## Cleaning DateTime Columns

# %% [markdown]
# 14. __Convert__ the datatype in the column __"release_date"__ __to datetime__. Set invalid values as NaN.

# %%
data["release_date"] = pd.to_datetime("release_date", errors="coerce")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4428 non-null   object
#  1   budget_musd            8794 non-null   float64
#  2   genres                 42468 non-null  object
#  3   id                     42465 non-null  float64
#  4   original_language      42462 non-null  object
#  5   overview               41716 non-null  object
#  6   popularity             42462 non-null  float64
#  7   poster_path            42359 non-null  object
#  8   production_companies   42462 non-null  object
#  9   production_countries   42462 non-null  object
#  10  release_date           0 non-null      datetime64[ns]
#  11  revenue_musd           42462 non-null  float64
#  12  runtime                42304 non-null  float64
#  13  spoken_languages       42462 non-null  object
#  14  status                 42406 non-null  object
#  15  tagline                19750 non-null  object
#  16  title                  42462 non-null  object
#  17  vote_average           42462 non-null  float64
#  18  vote_count             42462 non-null  float64
# dtypes: datetime64[ns](1), float64(7), object(11)
# memory usage: 6.6+ MB

# %%
data["release_date"].value_counts(dropna= False).head()
# Out:
# NaT    45466
# Name: release_date, dtype: int64

# %% [markdown]
# ## Cleaning Text / String Columns

# %% [markdown]
# 15. __Analyze__ the text columns "overview" and "tagline". Try to identify __missing data that is not represented by NaN__ (e.g. "No Data"). __Replace as NaN__ (np.nan)!

# %%
data["overview"].value_counts()
# Out:
# No overview found.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   117
# No Overview                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            6
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        4
# King Lear, old and tired, divides his kingdom among his daughters, giving great importance to their protestations of love for him. When Cordelia, youngest and most honest, refuses to idly flatter the old man in return for favor, he banishes her and turns for support to his remaining daughters. But Goneril and Regan have no love for him and instead plot to take all his power from him. In a parallel, Lear's loyal courtier Gloucester favors his illegitimate son Edmund after being told lies about his faithful son Edgar. Madness and tragedy befall both ill-starred fathers.                                                                         3
# No movie overview available.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           3
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# A unique documentary about troops' experiences in Iraq and Afghanistan, based on writings by soldiers, Marines, and air men.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# Inspector Amar Damjee discovers a terrifying crime in the street when he saves the lives of bus passengers. Now his job is as a police inspector to identify the terrorists. Suddenly, when a police commisioner's daughter is killed in a homicide, Amar is framed for it and goes to jail. When he escapes along with the other prisoners accidently, he goes out to prove his innocence and find the man behind this, which Amar also discovers that he was his parent's killer too.                                                                                                                                                                                1
# In the year 2022, a ruthless prison warden has created the ultimate solution for his most troublesome and violent inmates: Absolom, a secret jungle island where prisoners are abandoned and left to die. But Marine Captain John Robbins, convicted of murdering a commanding officer, is determined to escape the island in order to reveal the truth behind his murderous actions and clear his name.                                                                                                                                                                                                                                                               1
# London, modern day: Joe, a mild mannered young man is bored by his life. When his beloved brother is murdered Joe finds solace in Piggy, one of his brother's old friends. Piggy helps Joe to cope with grief, intent on saving him and helping him get justice for his brother's killing. As their friendship grows Joe finds himself in an increasing dangerous and murky world of violence and revenge. As Joe life collapses around him he starts to question who Piggy really is, and how honest he's really been with him. When Joe confronts Piggy a series of events are put in place that lead to a disastrous climax. Written by Anonymous  (IMDb.com).      1
# Bud and Doyle are two losers who are doing nothing with their lives. Both of their girlfriends are actively involved in saving the environment, but the two friends couldn't care less about saving the Earth. One day, when a group of scientists begin a mission to live inside a "Bio-Dome" for a year without outside contact, Bud and Doyle mistakenly become part of the project themselves.                                                                                                                                                                                                                                                                     1
# Name: overview, Length: 41538, dtype: int64

# %%
data["overview"].replace("No overview found.", np.nan, inplace = True)
data["overview"].replace("No Overview", np.nan, inplace = True)
data["overview"].replace("No movie overview available.", np.nan, inplace = True)
data["overview"].replace("", np.nan, inplace = True)
data["overview"].replace("No overview yet.", np.nan, inplace = True)

# %%
data["tagline"].value_counts(dropna = False).head(20)
# Out:
# NaN                                                           25716
# Based on a true story.                                            7
# Trust no one.                                                     4
# Be careful what you wish for.                                     4
# -                                                                 4
# Who is John Galt?                                                 3
# Which one is the first to return - memory or the murderer?        3
# How far would you go?                                             3
# A Love Story                                                      3
# There are two sides to every love story.                          3
# The end is near.                                                  3
# Know Your Enemy                                                   3
# Some doors should never be opened.                                3
# There is no turning back                                          3
# Documentary                                                       3
# Classic Albums                                                    3
# This is my Story                                                  2
# What could go wrong?                                              2
# You never forget your first love.                                 2
# The band you know. The story you don't.                           2
# Name: tagline, dtype: int64

# %%
data["tagline"] = data["tagline"].replace("-", np.nan, inplace = True)

# %% [markdown]
# ## Removing Duplicates

# %% [markdown]
# 16. __Identify__ and __remove__ duplicates!

# %%
data[data.duplicated(keep = False)].sort_values(by = "id")
# Out:
#       belongs_to_collection  budget_musd                         genres  \
# 7345                    NaN          NaN           Crime|Drama|Thriller
# 9165                    NaN          NaN           Crime|Drama|Thriller
# 24844                   NaN          NaN                   Comedy|Drama
# 14012                   NaN          NaN                   Comedy|Drama
# 22151                   NaN          NaN  Action|Horror|Science Fiction
# ...                     ...          ...                            ...
# 45432                   NaN          NaN                            NaN
# 45434                   NaN          NaN                            NaN
# 45452                   NaN          NaN                            NaN
# 45464                   NaN          NaN                            NaN
# 45465                   NaN          NaN                            NaN
#
#             id original_language  \
# 7345    5511.0                fr
# 9165    5511.0                fr
# 24844  11115.0                en
# 14012  11115.0                en
# 22151  18440.0                en
# ...        ...               ...
# 45432      NaN               NaN
# 45434      NaN               NaN
# 45452      NaN               NaN
# 45464      NaN               NaN
# 45465      NaN               NaN
#
#                                                 overview  popularity  \
# 7345   Hitman Jef Costello is a perfectionist who alw...    9.091288
# 9165   Hitman Jef Costello is a perfectionist who alw...    9.091288
# 24844  As an ex-gambler teaches a hot-shot college ki...    6.880365
# 14012  As an ex-gambler teaches a hot-shot college ki...    6.880365
# 22151  When a comet strikes Earth and kicks up a clou...    1.436085
# ...                                                  ...         ...
# 45432                                                NaN         NaN
# 45434                                                NaN         NaN
# 45452                                                NaN         NaN
# 45464                                                NaN         NaN
# 45465                                                NaN         NaN
#
#                             poster_path  \
# 7345   /cvNW8IXigbaMNo4gKEIps0NGnhA.jpg
# 9165   /cvNW8IXigbaMNo4gKEIps0NGnhA.jpg
# 24844  /kHaBqrrozaG7rj6GJg3sUCiM29B.jpg
# 14012  /kHaBqrrozaG7rj6GJg3sUCiM29B.jpg
# 22151  /tWCyKXHuSrQdLAvNeeVJBnhf1Yv.jpg
# ...                                 ...
# 45432                               NaN
# 45434                               NaN
# 45452                               NaN
# 45464                               NaN
# 45465                               NaN
#
#                                     production_companies  \
# 7345   Fida cinematografica|Compagnie Industrielle et...
# 9165   Fida cinematografica|Compagnie Industrielle et...
# 24844  Andertainment Group|Crescent City Pictures|Tag...
# 14012  Andertainment Group|Crescent City Pictures|Tag...
# 22151
# ...                                                  ...
# 45432                                                NaN
# 45434                                                NaN
# 45452                                                NaN
# 45464                                                NaN
# 45465                                                NaN
#
#            production_countries release_date  revenue_musd  runtime  \
# 7345               France|Italy          NaT      0.039481    105.0
# 9165               France|Italy          NaT      0.039481    105.0
# 24844  United States of America          NaT      0.000000     85.0
# 14012  United States of America          NaT      0.000000     85.0
# 22151  United States of America          NaT      0.000000     89.0
# ...                         ...          ...           ...      ...
# 45432                       NaN          NaT           NaN      NaN
# 45434                       NaN          NaT           NaN      NaN
# 45452                       NaN          NaT           NaN      NaN
# 45464                       NaN          NaT           NaN      NaN
# 45465                       NaN          NaT           NaN      NaN
#
#       spoken_languages    status tagline             title  vote_average  \
# 7345          Français  Released    None       Le Samouraï           7.9
# 9165          Français  Released    None       Le Samouraï           7.9
# 24844          English  Released    None              Deal           5.2
# 14012          English  Released    None              Deal           5.2
# 22151          English  Released    None  Days of Darkness           5.0
# ...                ...       ...     ...               ...           ...
# 45432              NaN       NaN     NaN               NaN           NaN
# 45434              NaN       NaN     NaN               NaN           NaN
# 45452              NaN       NaN     NaN               NaN           NaN
# 45464              NaN       NaN     NaN               NaN           NaN
# 45465              NaN       NaN     NaN               NaN           NaN
#
#        vote_count
# 7345        187.0
# 9165        187.0
# 24844        22.0
# 14012        22.0
# 22151         5.0
# ...           ...
# 45432         NaN
# 45434         NaN
# 45452         NaN
# 45464         NaN
# 45465         NaN
#
# [3027 rows x 19 columns]

# %%
data.drop_duplicates(inplace=True)

# %%
data[data.duplicated("id", keep = False)].sort_values(by = "id")
# Out:
#       belongs_to_collection  budget_musd  \
# 33826                   NaN    30.000000
# 5865                    NaN    30.000000
# 4114     Pokémon Collection    16.000000
# 44821    Pokémon Collection    16.000000
# 44826    Pokémon Collection          NaN
# 5535     Pokémon Collection          NaN
# 15765                   NaN     0.002500
# 11342                   NaN     0.002500
# 10419                   NaN     1.600000
# 12066                   NaN     1.600000
# 5130                    NaN    26.000000
# 33743                   NaN    26.000000
# 15074                   NaN     0.000004
# 949                     NaN     0.000004
# 9576                    NaN    10.000000
# 26625                   NaN    10.000000
# 11155                   NaN    40.000000
# 20843                   NaN    40.000000
# 21116                   NaN          NaN
# 2564                    NaN          NaN
# 20899                   NaN          NaN
# 5710                    NaN          NaN
# 4356                    NaN     3.512454
# 23534                   NaN     3.512454
# 83                      NaN          NaN
# 19730                   NaN          NaN
# 29503                   NaN          NaN
# 35587                   NaN          NaN
#
#                                                   genres        id  \
# 33826                Comedy|Crime|Drama|Romance|Thriller    4912.0
# 5865                 Comedy|Crime|Drama|Romance|Thriller    4912.0
# 4114           Adventure|Fantasy|Animation|Action|Family   10991.0
# 44821          Adventure|Fantasy|Animation|Action|Family   10991.0
# 44826  Adventure|Fantasy|Animation|Science Fiction|Fa...   12600.0
# 5535   Adventure|Fantasy|Animation|Science Fiction|Fa...   12600.0
# 15765                               Drama|Comedy|Foreign   13209.0
# 11342                               Drama|Comedy|Foreign   13209.0
# 10419                                Drama|Crime|Mystery   14788.0
# 12066                                Drama|Crime|Mystery   14788.0
# 5130           Adventure|Family|Science Fiction|Thriller   15028.0
# 33743          Adventure|Family|Science Fiction|Thriller   15028.0
# 15074                                  Drama|Romance|War   22649.0
# 949                                    Drama|Romance|War   22649.0
# 9576                 Drama|Horror|Music|Romance|TV Movie   69234.0
# 26625                Drama|Horror|Music|Romance|TV Movie   69234.0
# 11155                                    Adventure|Drama   77221.0
# 20843                                    Adventure|Drama   77221.0
# 21116                                        Documentary   84198.0
# 2564                                         Documentary   84198.0
# 20899                                              Drama  109962.0
# 5710                                               Drama  109962.0
# 4356                                               Drama  110428.0
# 23534                                              Drama  110428.0
# 83                                                   NaN       NaN
# 19730  Carousel Productions|Vision View Entertainment...       NaN
# 29503  Aniplex|GoHands|BROSTA TV|Mardock Scramble Pro...       NaN
# 35587  Odyssey Media|Pulser Productions|Rogue State|T...       NaN
#
#       original_language                                           overview  \
# 33826                en  Television made him famous, but his biggest hi...
# 5865                 en  Television made him famous, but his biggest hi...
# 4114                 ja  When Molly Hale's sadness of her father's disa...
# 44821                ja  When Molly Hale's sadness of her father's disa...
# 44826                ja  All your favorite Pokémon characters are back,...
# 5535                 ja  All your favorite Pokémon characters are back,...
# 15765                fa  Since women are banned from soccer matches, Ir...
# 11342                fa  Since women are banned from soccer matches, Ir...
# 10419                en  Set against the backdrop of a decaying Midwest...
# 12066                en  Set against the backdrop of a decaying Midwest...
# 5130                 en  Until now, Zak Gibbs' greatest challenge has b...
# 33743                en  Until now, Zak Gibbs' greatest challenge has b...
# 15074                en  British nurse Catherine Barkley (Helen Hayes) ...
# 949                  en  British nurse Catherine Barkley (Helen Hayes) ...
# 9576                 en  Count de Chagnie has discovered Christine's si...
# 26625                en  Count de Chagnie has discovered Christine's si...
# 11155                en  On the Arabian Peninsula in the 1930s, two war...
# 20843                en  On the Arabian Peninsula in the 1930s, two war...
# 21116                en  Using personal stories, this powerful document...
# 2564                 en  Using personal stories, this powerful document...
# 20899                en  Two literary women compete for 20 years: one w...
# 5710                 en  Two literary women compete for 20 years: one w...
# 4356                 fr  Winter, 1915. Confined by her family to an asy...
# 23534                fr  Winter, 1915. Confined by her family to an asy...
# 83                  NaN                                                NaN
# 19730             104.0                                           Released
# 29503              68.0                                           Released
# 35587              82.0                                           Released
#
#        popularity                          poster_path  \
# 33826    7.645827     /o3Im9nPLAgtlw1j2LtpMebAotSe.jpg
# 5865    11.331072     /o3Im9nPLAgtlw1j2LtpMebAotSe.jpg
# 4114    10.264597     /5ILjS6XB5deiHop8SXPsYxXWVPE.jpg
# 44821    6.480376     /5ILjS6XB5deiHop8SXPsYxXWVPE.jpg
# 44826    6.080108     /bqL0PVHbQ8Jmw3Njcl38kW0CoeM.jpg
# 5535     7.072301     /bqL0PVHbQ8Jmw3Njcl38kW0CoeM.jpg
# 15765    1.529879     /nfkOkpudNNIjRrf0mTFVoiGzHyc.jpg
# 11342    1.528960     /nfkOkpudNNIjRrf0mTFVoiGzHyc.jpg
# 10419    3.185256     /w56oo9nREcF54sNXVYuE9QxZFjT.jpg
# 12066    3.008299     /w56oo9nREcF54sNXVYuE9QxZFjT.jpg
# 5130     5.373623     /xGhDPrBz9mJN8CsIjA23jQSd3sc.jpg
# 33743    4.920175     /xGhDPrBz9mJN8CsIjA23jQSd3sc.jpg
# 15074    2.411191     /k0MF0IIbJ2PfOIku2KyraXL72d8.jpg
# 949      1.914697     /k0MF0IIbJ2PfOIku2KyraXL72d8.jpg
# 9576     0.441872     /ole8e9YQwvHoKVpWO0lgfLFFemc.jpg
# 26625    0.438490     /ole8e9YQwvHoKVpWO0lgfLFFemc.jpg
# 11155    6.652197     /iQd7zWhSeCe3cgdPcLIDXjGfdzL.jpg
# 20843    6.475665     /iQd7zWhSeCe3cgdPcLIDXjGfdzL.jpg
# 21116    1.673307     /jn8L1QdWWX5c0NUOLjzaSXtZrbt.jpg
# 2564     0.501046     /jn8L1QdWWX5c0NUOLjzaSXtZrbt.jpg
# 20899   10.396878     /tOflyY8eUFWubLKJH7fKg4KwpCl.jpg
# 5710    12.180836     /tOflyY8eUFWubLKJH7fKg4KwpCl.jpg
# 4356     0.134014     /sGMPDg6je1zKi0TiX9b4pP6yN02.jpg
# 23534    0.110065     /sGMPDg6je1zKi0TiX9b4pP6yN02.jpg
# 83            NaN                                  NaN
# 19730         NaN                         Midnight Man
# 29503         NaN  Mardock Scramble: The Third Exhaust
# 35587         NaN                     Avalanche Sharks
#
#                                     production_companies  \
# 33826         Miramax Films|Allied Filmmakers|Mad Chance
# 5865          Miramax Films|Allied Filmmakers|Mad Chance
# 4114   TV Tokyo|4 Kids Entertainment|Nintendo|Pikachu...
# 44821  TV Tokyo|4 Kids Entertainment|Nintendo|Pikachu...
# 44826
# 5535
# 15765                      Jafar Panahi Film Productions
# 11342                      Jafar Panahi Film Productions
# 10419                    Magnolia Pictures|Extension 765
# 12066                    Magnolia Pictures|Extension 765
# 5130   Paramount Pictures|Nickelodeon Movies|Valhalla...
# 33743  Paramount Pictures|Nickelodeon Movies|Valhalla...
# 15074                                 Paramount Pictures
# 949                                   Paramount Pictures
# 9576   Beta Film|Reteitalia|TF1|Hexatel|Saban/Scheric...
# 26625  Beta Film|Reteitalia|TF1|Hexatel|Saban/Scheric...
# 11155  France 2 Cinéma|Quinta Communications|Carthago...
# 20843  France 2 Cinéma|Quinta Communications|Carthago...
# 21116
# 2564
# 20899                   Metro-Goldwyn-Mayer (MGM)|Jaquet
# 5710                    Metro-Goldwyn-Mayer (MGM)|Jaquet
# 4356   Canal+|Arte France Cinéma|3B Productions|C.R.R...
# 23534  Canal+|Arte France Cinéma|3B Productions|C.R.R...
# 83                                                   NaN
# 19730                                                NaN
# 29503                                                NaN
# 35587                                                NaN
#
#                                 production_countries release_date  \
# 33826                       United States of America          NaT
# 5865                        United States of America          NaT
# 4114                                           Japan          NaT
# 44821                                          Japan          NaT
# 44826                 Japan|United States of America          NaT
# 5535                  Japan|United States of America          NaT
# 15765                                           Iran          NaT
# 11342                                           Iran          NaT
# 10419                       United States of America          NaT
# 12066                       United States of America          NaT
# 5130                        United States of America          NaT
# 33743                       United States of America          NaT
# 15074                       United States of America          NaT
# 949                         United States of America          NaT
# 9576   France|Germany|Italy|United States of America          NaT
# 26625  France|Germany|Italy|United States of America          NaT
# 11155                     France|Italy|Qatar|Tunisia          NaT
# 20843                     France|Italy|Qatar|Tunisia          NaT
# 21116                       United States of America          NaT
# 2564                        United States of America          NaT
# 20899                       United States of America          NaT
# 5710                        United States of America          NaT
# 4356                                          France          NaT
# 23534                                         France          NaT
# 83                                               NaN          NaT
# 19730                                            NaN          NaT
# 29503                                            NaN          NaT
# 35587                                            NaN          NaT
#
#        revenue_musd  runtime  spoken_languages    status tagline  \
# 33826     33.013805    113.0           English  Released    None
# 5865      33.013805    113.0           English  Released    None
# 4114      68.411275     93.0           English  Released    None
# 44821     68.411275     93.0           English  Released    None
# 44826     28.023563     75.0               日本語  Released    None
# 5535      28.023563     75.0               日本語  Released    None
# 15765      0.000000     93.0             فارسی  Released    None
# 11342      0.000000     93.0             فارسی  Released    None
# 10419      0.000000     73.0           English  Released    None
# 12066      0.000000     73.0           English  Released    None
# 5130      38.793283     94.0     Český|English  Released    None
# 33743     38.793283     94.0     Český|English  Released    None
# 15074      0.000025     89.0           English  Released    None
# 949        0.000025     89.0           English  Released    None
# 9576       0.000000    168.0  English|Italiano  Released    None
# 26625      0.000000    168.0  English|Italiano  Released    None
# 11155      5.446000    130.0           English  Released    None
# 20843      5.446000    130.0           English  Released    None
# 21116      0.000000     84.0           English  Released    None
# 2564       0.000000     84.0           English  Released    None
# 20899      0.000000    115.0           English  Released    None
# 5710       0.000000    115.0           English  Released    None
# 4356       0.115860     95.0          Français  Released    None
# 23534      0.115860     95.0          Français  Released    None
# 83              NaN      NaN               NaN       NaN    None
# 19730           NaN      NaN               NaN       NaN    None
# 29503           NaN      NaN               NaN       NaN    None
# 35587           NaN      NaN               NaN       NaN    None
#
#                                              title  vote_average  vote_count
# 33826              Confessions of a Dangerous Mind           6.6       281.0
# 5865               Confessions of a Dangerous Mind           6.6       281.0
# 4114                 Pokémon: Spell of the Unknown           6.0       143.0
# 44821                Pokémon: Spell of the Unknown           6.0       144.0
# 44826  Pokémon 4Ever: Celebi - Voice of the Forest           5.7        82.0
# 5535   Pokémon 4Ever: Celebi - Voice of the Forest           5.7        82.0
# 15765                                      Offside           6.7        27.0
# 11342                                      Offside           6.7        27.0
# 10419                                       Bubble           6.4        36.0
# 12066                                       Bubble           6.4        36.0
# 5130                                 Clockstoppers           4.9        89.0
# 33743                                Clockstoppers           4.9        90.0
# 15074                           A Farewell to Arms           6.2        29.0
# 949                             A Farewell to Arms           6.2        29.0
# 9576                      The Phantom of the Opera           5.0         3.0
# 26625                     The Phantom of the Opera           5.0         3.0
# 11155                                   Black Gold           5.9        77.0
# 20843                                   Black Gold           5.9        77.0
# 21116                         A Place at the Table           6.9         7.0
# 2564                          A Place at the Table           6.9         7.0
# 20899                              Rich and Famous           4.9         7.0
# 5710                               Rich and Famous           4.9         7.0
# 4356                          Camille Claudel 1915           7.0        20.0
# 23534                         Camille Claudel 1915           7.0        20.0
# 83                                             NaN           NaN         NaN
# 19730                                          NaN           NaN         NaN
# 29503                                          NaN           NaN         NaN
# 35587                                          NaN           NaN         NaN

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Handling Missing Values & Removing Observations

# %%
data.isna().sum()
# Out:
# belongs_to_collection    38027
# budget_musd              33661
# genres                       1
# id                           4
# original_language            7
# overview                   880
# popularity                   7
# poster_path                110
# production_companies         7
# production_countries         7
# release_date             42454
# revenue_musd                 7
# runtime                    165
# spoken_languages             7
# status                      63
# tagline                  42454
# title                        7
# vote_average                 7
# vote_count                   7
# dtype: int64

# %% [markdown]
# 17. __Drop__ all rows/movies with unknown __id__ or __title__.

# %%
data.dropna(subset = ["id", "title"], inplace=True)

# %%
data.isna().sum()
# Out:
# belongs_to_collection    38021
# budget_musd              33654
# genres                       0
# id                           0
# original_language            6
# overview                   879
# popularity                   0
# poster_path                106
# production_companies         0
# production_countries         0
# release_date             42447
# revenue_musd                 0
# runtime                    158
# spoken_languages             0
# status                      56
# tagline                  42447
# title                        0
# vote_average                 0
# vote_count                   0
# dtype: int64

# %%
data.id = data.id.astype("int")

# %%
data.isna().sum()
# Out:
# belongs_to_collection    38021
# budget_musd              33654
# genres                       0
# id                           0
# original_language            6
# overview                   879
# popularity                   0
# poster_path                106
# production_companies         0
# production_countries         0
# release_date             42447
# revenue_musd                 0
# runtime                    158
# spoken_languages             0
# status                      56
# tagline                  42447
# title                        0
# vote_average                 0
# vote_count                   0
# dtype: int64

# %% [markdown]
# ## Final (Cleaning) Steps

# %% [markdown]
# 19. __Keep__ only those rows/movies in the df with __status "Released"__. Then __drop__ the column "status".

# %%
data.columns
# Out:
# Index(['belongs_to_collection', 'budget_musd', 'genres', 'id',
#        'original_language', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue_musd', 'runtime', 'spoken_languages', 'status', 'tagline',
#        'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
data = data[data["status"]=="Released"].copy()

# %%
data.drop(columns=["status"], inplace=True)

# %% [markdown]
# 20. The Order of the columns should be as follows:

# %%
col = ["id", "title", "tagline", "release_date", "genres", "belongs_to_collection", 
"original_language", "budget_musd", "revenue_musd", "production_companies",
"production_countries", "vote_count", "vote_average", "popularity", "runtime",
"overview", "spoken_languages", "poster_path"]

# %%
data = data.loc[:, col]

# %% [markdown]
# 21. __Reset__ the Index and create a __RangeIndex__.

# %%
data.reset_index(drop = True, inplace=True)

# %% [markdown]
# 22. __Save__ the cleaned dataset in a __csv-file__.

# %%
data.to_csv("movies_clean.csv", index = False)

# %%
data = pd.read_csv("movies_clean.csv")
data.head().T
# Out:
#                                                                        0  \
# id                                                                   862
# title                                                          Toy Story
# tagline                                                              NaN
# release_date                                                         NaN
# genres                                           Animation|Comedy|Family
# belongs_to_collection                               Toy Story Collection
# original_language                                                     en
# budget_musd                                                           30
# revenue_musd                                                     373.554
# production_companies                             Pixar Animation Studios
# production_countries                            United States of America
# vote_count                                                          5415
# vote_average                                                         7.7
# popularity                                                       21.9469
# runtime                                                               81
# overview               Led by Woody, Andy's toys live happily in his ...
# spoken_languages                                                 English
# poster_path                             /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
#
#                                                                        1  \
# id                                                                  8844
# title                                                            Jumanji
# tagline                                                              NaN
# release_date                                                         NaN
# genres                                          Adventure|Fantasy|Family
# belongs_to_collection                                                NaN
# original_language                                                     en
# budget_musd                                                           65
# revenue_musd                                                     262.797
# production_companies   TriStar Pictures|Teitler Film|Interscope Commu...
# production_countries                            United States of America
# vote_count                                                          2413
# vote_average                                                         6.9
# popularity                                                       17.0155
# runtime                                                              104
# overview               When siblings Judy and Peter discover an encha...
# spoken_languages                                        English|Français
# poster_path                             /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
#
#                                                                        2  \
# id                                                                 15602
# title                                                   Grumpier Old Men
# tagline                                                              NaN
# release_date                                                         NaN
# genres                                                    Romance|Comedy
# belongs_to_collection                          Grumpy Old Men Collection
# original_language                                                     en
# budget_musd                                                          NaN
# revenue_musd                                                           0
# production_companies                         Warner Bros.|Lancaster Gate
# production_countries                            United States of America
# vote_count                                                            92
# vote_average                                                         6.5
# popularity                                                       11.7129
# runtime                                                              101
# overview               A family wedding reignites the ancient feud be...
# spoken_languages                                                 English
# poster_path                             /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
#
#                                                                        3  \
# id                                                                 31357
# title                                                  Waiting to Exhale
# tagline                                                              NaN
# release_date                                                         NaN
# genres                                              Comedy|Drama|Romance
# belongs_to_collection                                                NaN
# original_language                                                     en
# budget_musd                                                           16
# revenue_musd                                                     81.4522
# production_companies              Twentieth Century Fox Film Corporation
# production_countries                            United States of America
# vote_count                                                            34
# vote_average                                                         6.1
# popularity                                                       3.85949
# runtime                                                              127
# overview               Cheated on, mistreated and stepped on, the wom...
# spoken_languages                                                 English
# poster_path                             /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
#
#                                                                        4
# id                                                                 11862
# title                                        Father of the Bride Part II
# tagline                                                              NaN
# release_date                                                         NaN
# genres                                                            Comedy
# belongs_to_collection                     Father of the Bride Collection
# original_language                                                     en
# budget_musd                                                          NaN
# revenue_musd                                                     76.5789
# production_companies           Sandollar Productions|Touchstone Pictures
# production_countries                            United States of America
# vote_count                                                           173
# vote_average                                                         5.7
# popularity                                                       8.38752
# runtime                                                              106
# overview               Just when George Banks has recovered from his ...
# spoken_languages                                                 English
# poster_path                             /e64sOI48hQXyru7naBFyssKFxVd.jpg
